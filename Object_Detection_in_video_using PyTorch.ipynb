jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame323.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame324.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame325.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame326.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame327.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame328.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame329.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame330.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame331.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame332.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame333.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame334.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame335.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame336.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame337.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame338.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame339.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame340.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame341.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame342.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame343.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame344.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame345.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame346.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame347.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame348.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame349.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame350.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame351.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame352.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame353.jpg
# Read a new frame: True
# Saved /Users/shabarivignesh/Data 255 - Deep Learning/frames/frame354.jpg
# Read a new frame: False

# %% [markdown]
# This code captures frames from a video file and saves each frame as a `.jpg` image in a specified directory. It uses OpenCV (`cv2`) to read the video and extract frames. If the output directory doesn't exist, it creates one. The loop iterates through the video, saving frames sequentially with filenames like `frame0.jpg`, `frame1.jpg`, etc., until all frames are processed. The video capture object is then released to free up resources.

# %% [markdown]
# ## Step 2 - Vehicle Detection and Bounding Box Inference on Video Frames

# %%
import torch
import torchvision
import cv2
from torchvision.transforms import functional as F
import os

COCO_LABELS = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat',
    'traffic light', 'fire hydrant', 'N/A', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee',
    'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli',
    'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A', 'toilet',
    'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

input_frames_dir = '/Users/shabarivignesh/Data 255 - Deep Learning/frames/'
output_frames_dir = '/Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/'

if not os.path.exists(output_frames_dir):
    os.makedirs(output_frames_dir)

def draw_bounding_boxes(image, boxes, labels):
    for box, label in zip(boxes, labels):
        x1, y1, x2, y2 = map(int, box)
        cv2.rectangle(image, (x1, y1), (x2, y2), color=(255, 0, 0), thickness=2)
        label_text = COCO_LABELS[label]
        cv2.putText(image, label_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    return image

frame_filenames = sorted([f for f in os.listdir(input_frames_dir) if f.endswith('.jpg')])

for frame_filename in frame_filenames:
    frame_path = os.path.join(input_frames_dir, frame_filename)
    image = cv2.imread(frame_path)
    img_tensor = F.to_tensor(image).unsqueeze(0)

    with torch.no_grad():
        predictions = model(img_tensor)

    boxes = predictions[0]['boxes'].cpu().numpy()
    labels = predictions[0]['labels'].cpu().numpy()

    image_with_boxes = draw_bounding_boxes(image, boxes, labels)

    output_frame_path = os.path.join(output_frames_dir, frame_filename)
    cv2.imwrite(output_frame_path, image_with_boxes)
    print(f'Saved frame with bounding boxes and labels: {output_frame_path}')
# Out:
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame0.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame1.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame10.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame100.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame101.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame102.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame103.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame104.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame105.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame106.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame107.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame108.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame109.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame11.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame110.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame111.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame112.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame113.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame114.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame115.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame116.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame117.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame118.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame119.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame12.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame120.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame121.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame122.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame123.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame124.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame125.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame126.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame127.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame128.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame129.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame13.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame130.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame131.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame132.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame133.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame134.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame135.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame136.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame137.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame138.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame139.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame14.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame140.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame141.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame142.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame143.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame144.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame145.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame146.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame147.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame148.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame149.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame15.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame150.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame151.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame152.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame153.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame154.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame155.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame156.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame157.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame158.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame159.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame16.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame160.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame161.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame162.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame163.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame164.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame165.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame166.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame167.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame168.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame169.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame17.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame170.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame171.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame172.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame173.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame174.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame175.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame176.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame177.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame178.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame179.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame18.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame180.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame181.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame182.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame183.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame184.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame185.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame186.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame187.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame188.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame189.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame19.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame190.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame191.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame192.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame193.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame194.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame195.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame196.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame197.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame198.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame199.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame2.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame20.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame200.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame201.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame202.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame203.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame204.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame205.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame206.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame207.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame208.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame209.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame21.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame210.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame211.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame212.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame213.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame214.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame215.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame216.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame217.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame218.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame219.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame22.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame220.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame221.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame222.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame223.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame224.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame225.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame226.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame227.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame228.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame229.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame23.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame230.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame231.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame232.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame233.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame234.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame235.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame236.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame237.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame238.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame239.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame24.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame240.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame241.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame242.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame243.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame244.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame245.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame246.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame247.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame248.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame249.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame25.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame250.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame251.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame252.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame253.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame254.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame255.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame256.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame257.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame258.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame259.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame26.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame260.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame261.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame262.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame263.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame264.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame265.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame266.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame267.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame268.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame269.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame27.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame270.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame271.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame272.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame273.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame274.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame275.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame276.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame277.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame278.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame279.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame28.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame280.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame281.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame282.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame283.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame284.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame285.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame286.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame287.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame288.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame289.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame29.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame290.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame291.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame292.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame293.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame294.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame295.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame296.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame297.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame298.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame299.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame3.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame30.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame300.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame301.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame302.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame303.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame304.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame305.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame306.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame307.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame308.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame309.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame31.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame310.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame311.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame312.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame313.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame314.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame315.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame316.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame317.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame318.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame319.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame32.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame320.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame321.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame322.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame323.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame324.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame325.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame326.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame327.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame328.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame329.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame33.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame330.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame331.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame332.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame333.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame334.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame335.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame336.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame337.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame338.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame339.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame34.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame340.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame341.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame342.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame343.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame344.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame345.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame346.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame347.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame348.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame349.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame35.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame350.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame351.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame352.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame353.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame354.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame36.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame37.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame38.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame39.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame4.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame40.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame41.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame42.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame43.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame44.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame45.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame46.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame47.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame48.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame49.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame5.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame50.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame51.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame52.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame53.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame54.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame55.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame56.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame57.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame58.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame59.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame6.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame60.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame61.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame62.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame63.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame64.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame65.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame66.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame67.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame68.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame69.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame7.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame70.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame71.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame72.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame73.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame74.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame75.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame76.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame77.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame78.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame79.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame8.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame80.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame81.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame82.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame83.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame84.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame85.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame86.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame87.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame88.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame89.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame9.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame90.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame91.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame92.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame93.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame94.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame95.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame96.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame97.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame98.jpg
# Saved frame with bounding boxes and labels: /Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/frame99.jpg

# %% [markdown]
# This script utilizes a pre-trained Faster R-CNN model to detect objects in a series of image frames. It begins by loading the Faster R-CNN model with a ResNet-50 backbone, specifically designed for object detection tasks. Images are read from an input directory, and for each image, the model identifies objects, drawing bounding boxes around them and labeling them with the corresponding COCO dataset labels. The processed images, now containing bounding boxes and labels, are saved to an output directory. The script also ensures that the output directory exists, creating it if necessary, and handles each image in sequence by first converting it to a tensor before passing it to the model for inference.

# %% [markdown]
# ## Step 3 - Compile image frames into a video

# %%
import re

input_frames_dir = '/Users/shabarivignesh/Data 255 - Deep Learning/frames_with_boxes/'
output_video_path = '/Users/shabarivignesh/Data 255 - Deep Learning/output_video.mp4'

def numerical_sort(value):
    numbers = re.findall(r'\d+', value)
    return int(numbers[0]) if numbers else -1

frame_filenames = sorted([f for f in os.listdir(input_frames_dir) if f.endswith('.jpg')], key=numerical_sort)

first_frame_path = os.path.join(input_frames_dir, frame_filenames[0])
first_frame = cv2.imread(first_frame_path)
height, width, layers = first_frame.shape

fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = 30  
output_video = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))


for frame_filename in frame_filenames:
    frame_path = os.path.join(input_frames_dir, frame_filename)
    frame = cv2.imread(frame_path)
    output_video.write(frame)


output_video.release()

print(f"Video saved to {output_video_path}")
# Out:
# Video saved to /Users/shabarivignesh/Data 255 - Deep Learning/output_video.mp4

# %% [markdown]
# This script combines a series of image frames into a video. It starts by reading frames from a specified directory, sorts them numerically to maintain the correct order, and uses OpenCV's `VideoWriter` to compile them into an `.mp4` video file. The first frame is used to determine the video's dimensions, and each subsequent frame is added to the output video file. After all frames are processed, the video file is saved to a specified output path.
